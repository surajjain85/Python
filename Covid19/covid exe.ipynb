# %% [markdown]
# https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data/csse_covid_19_daily_reports

# %% [markdown]
# Write a Python program to display first 5 rows from COVID-19 dataset. Also print the dataset information and check the missing values.

# %%
import pandas as pd
covid_data=pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-17-2020.csv")
covid_data
# Out:
#     Province/State                  Country/Region          Last Update  \
# 0            Hubei                           China  2020-03-17T11:53:10
# 1              NaN                           Italy  2020-03-17T18:33:02
# 2              NaN                            Iran  2020-03-17T15:13:09
# 3              NaN                           Spain  2020-03-17T20:53:02
# 4              NaN                         Germany  2020-03-17T18:53:02
# ..             ...                             ...                  ...
# 271            NaN                        Guernsey  2020-03-17T18:33:03
# 272            NaN                          Jersey  2020-03-17T18:33:03
# 273            NaN                     Puerto Rico  2020-03-17T16:13:14
# 274            NaN           Republic of the Congo  2020-03-17T21:33:03
# 275            NaN  occupied Palestinian territory  2020-03-11T20:53:02
#
#      Confirmed  Deaths  Recovered  Latitude  Longitude
# ...

# %%
covid_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  126 non-null    object
#  1   Country/Region  276 non-null    object
#  2   Last Update     276 non-null    object
#  3   Confirmed       276 non-null    int64
#  4   Deaths          276 non-null    int64
#  5   Recovered       276 non-null    int64
#  6   Latitude        276 non-null    float64
#  7   Longitude       276 non-null    float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 17.4+ KB

# %%
covid_data.isna().sum()
# Out:
# Province/State    150
# Country/Region      0
# Last Update         0
# Confirmed           0
# Deaths              0
# Recovered           0
# Latitude            0
# Longitude           0
# dtype: int64

# %% [markdown]
# Get the latest number of confirmed, deaths, recovered and active cases of Novel Coronavirus Country wise

# %%
covid_data= pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-17-2020.csv')

# %%
covid_data['Active Cases']=covid_data['Confirmed']-covid_data['Deaths']-covid_data['Recovered']
covid_data['Active Cases']
# Out:
# 0       8685
# 1      26062
# 2       9792
# 3      10187
# 4       9166
#        ...
# 271        0
# 272        0
# 273        0
# 274        0
# 275        0
# Name: Active Cases, Length: 276, dtype: int64

# %%
result=covid_data.groupby('Country/Region')['Confirmed','Deaths','Recovered','Active Cases'].sum().reset_index()
result
# Out:
# C:\Users\suraj.jain\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                      Country/Region  Confirmed  Deaths  Recovered  \
# 0                       Afghanistan         20       0          1
# 1                           Albania         55       1          0
# 2                           Algeria         60       4         12
# 3                           Andorra         39       0          1
# 4               Antigua and Barbuda          1       0          0
# ..                              ...        ...     ...        ...
# 154                         Uruguay         29       0          0
# 155                      Uzbekistan         10       0          0
# 156                       Venezuela         33       0          0
# ...

# %% [markdown]
# rite a Python program to get the latest number of confirmed deaths and recovered people of Novel Coronavirus (COVID-19) cases Country/Region - Province/State wise.

# %%
data=covid_data.groupby(['Country/Region','Province/State'])['Confirmed','Deaths','Recovered'].max()
data
# Out:
# C:\Users\suraj.jain\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                              Confirmed  Deaths  Recovered
# Country/Region Province/State
# Australia      Australian Capital Territory          2       0          0
#                From Diamond Princess                 0       0          0
#                New South Wales                     210       4          4
#                Northern Territory                    1       0          0
#                Queensland                           78       0          8
# ...                                                ...     ...        ...
# US             Wyoming                              11       0          0
# United Kingdom Cayman Islands                        1       1          0
# ...

# %% [markdown]
# Write a Python program to get the Chinese province wise cases of confirmed, deaths and recovered cases of Novel Coronavirus (COVID-19)

# %%
c_data=covid_data[covid_data['Country/Region']=='China']
c_data
# Out:
#      Province/State Country/Region          Last Update  Confirmed  Deaths  \
# 0             Hubei          China  2020-03-17T11:53:10      67799    3111
# 12        Guangdong          China  2020-03-17T01:53:03       1364       8
# 14            Henan          China  2020-03-14T09:53:08       1273      22
# 16         Zhejiang          China  2020-03-17T02:13:21       1232       1
# 19            Hunan          China  2020-03-14T08:33:03       1018       4
# 20            Anhui          China  2020-03-11T02:18:14        990       6
# 22          Jiangxi          China  2020-03-12T02:13:04        935       1
# 24         Shandong          China  2020-03-17T00:33:02        761       7
# 28          Jiangsu          China  2020-03-15T01:53:02        631       0
# 29        Chongqing          China  2020-03-15T03:53:04        576       6
# 30          Sichuan          China  2020-03-17T08:33:02        540       3
# ...

# %%
c_data=c_data[['Province/State','Confirmed','Deaths','Recovered']]
c_data
# Out:
#      Province/State  Confirmed  Deaths  Recovered
# 0             Hubei      67799    3111      56003
# 12        Guangdong       1364       8       1307
# 14            Henan       1273      22       1250
# 16         Zhejiang       1232       1       1216
# 19            Hunan       1018       4       1014
# 20            Anhui        990       6        984
# 22          Jiangxi        935       1        934
# 24         Shandong        761       7        746
# 28          Jiangsu        631       0        631
# 29        Chongqing        576       6        570
# 30          Sichuan        540       3        520
# 31     Heilongjiang        482      13        456
# 32          Beijing        456       8        369
# 37         Shanghai        358       3        325
# 41            Hebei        318       6        310
# 42           Fujian        296       1        295
# 46          Guangxi        253       2        248
# 47          Shaanxi        246       3        236
# ...

# %% [markdown]
# Get the latest country wise deaths cases of Novel Coronavirus

# %%
data1=covid_data.groupby('Country/Region')['Confirmed','Deaths','Recovered']
# Out:
# C:\Users\suraj.jain\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
result=data1[data1['Deaths']>10][['Country/Region','Deaths']]
result
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-74e5e5bce060> in <module>
# ----> 1 result=data1[data1['Deaths']>10][['Country/Region','Deaths']]
#       2 result
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1646                 stacklevel=2,
#    1647             )
# -> 1648         return super().__getitem__(key)
#    1649
#    1650     def _gotitem(self, key, ndim: int, subset=None):
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     211     def __getitem__(self, key):
#     212         if self._selection is not None:
# --> 213             raise IndexError(f"Column(s) {self._selection} already selected")
#     214
#     215         if isinstance(key, (list, tuple, ABCSeries, ABCIndexClass, np.ndarray)):
#
# ...

# %% [markdown]
# List countries with all cases of Novel Coronavirus died

# %%
data=covid_data.groupby('Country/Region')['Confirmed','Deaths','Recovered'].sum()
data
# Out:
# C:\Users\suraj.jain\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                 Confirmed  Deaths  Recovered
# Country/Region
# Afghanistan                            20       0          1
# Albania                                55       1          0
# Algeria                                60       4         12
# Andorra                                39       0          1
# Antigua and Barbuda                     1       0          0
# ...                                   ...     ...        ...
# Uruguay                                29       0          0
# Uzbekistan                             10       0          0
# Venezuela                              33       0          0
# Vietnam                                66       0         16
# ...

# %%
result=data[data['Confirmed']==data['Deaths']]
result
# Out:
#                                 Confirmed  Deaths  Recovered
# Country/Region
# Guernsey                                0       0          0
# Jersey                                  0       0          0
# Puerto Rico                             0       0          0
# Republic of the Congo                   0       0          0
# Sudan                                   1       1          0
# occupied Palestinian territory          0       0          0

# %%
#result=result[['Country/Region','Confirmed','Deaths']]

result=result[result['Confirmed']>0]
result
# Out:
# Empty DataFrame
# Columns: [Confirmed, Deaths, Recovered]
# Index: []

# %% [markdown]
# Write a Python program to get the top 10 countries data (Last Update, Country/Region, Confirmed, Deaths, Recovered) of Novel Coronavirus (COVID-19)

# %%
import pandas as pd
covid_data= pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-18-2020.csv', usecols = ['Last Update', 'Country/Region', 'Confirmed', 'Deaths', 'Recovered'])

# %%
result=covid_data.groupby('Country/Region').max().sort_values(by='Confirmed',ascending=False)
result
# Out:
#                                Last Update  Confirmed  Deaths  Recovered
# Country/Region
# China                  2020-03-18T12:13:09      67800    3122      56927
# Italy                  2020-03-18T17:33:05      35713    2978       4025
# Iran                   2020-03-18T12:33:02      17361    1135       5389
# Spain                  2020-03-18T13:13:13      13910     623       1081
# Germany                2020-03-18T19:33:02      12327      28        105
# ...                                    ...        ...     ...        ...
# Guernsey               2020-03-17T18:33:03          0       0          0
# Jersey                 2020-03-17T18:33:03          0       0          0
# Puerto Rico            2020-03-17T16:13:14          0       0          0
# Republic of the Congo  2020-03-17T21:33:03          0       0          0
# The Gambia             2020-03-18T14:13:56          0       0          0
#
# [163 rows x 4 columns]

# %% [markdown]
# Write a Python program to visualize the state/province wise death cases of Novel Coronavirus (COVID-19) in USA

# %%
pip install plotly

# %%
import pandas as pd
#import plotly.express as px
covid_data= pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-17-2020.csv')

# %%
us_data = covid_data[covid_data['Country/Region']=='US'].drop(['Country/Region','Latitude', 'Longitude'], axis=1)

# %%
us_data = us_data[us_data.sum(axis = 1) > 0]
us_data = us_data.groupby(['Province/State'])['Deaths'].sum().reset_index()
us_data_death = us_data[us_data['Deaths'] > 0]

# %%
us_data_death
# Out:
#     Province/State  Deaths
# 4       California      12
# 5         Colorado       2
# 10         Florida       6
# 11         Georgia       1
# 16        Illinois       1
# 17         Indiana       2
# 19          Kansas       1
# 20        Kentucky       1
# 21       Louisiana       4
# 31          Nevada       1
# 33      New Jersey       3
# 35        New York      13
# 40          Oregon       1
# 44  South Carolina       1
# 45    South Dakota       1
# 47           Texas       1
# 51        Virginia       2
# 52      Washington      55
