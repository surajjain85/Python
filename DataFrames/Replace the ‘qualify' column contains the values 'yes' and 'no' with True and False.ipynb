# %% [markdown]
# Write a Pandas program to replace the ‘qualify' column contains the values 'yes' and 'no' with True and False.
#
# Sample DataFrame:
# exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
# 'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
# 'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
# 'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# Values for each column will be:
# name : ‘Suresh’, score: 15.5, attempts: 1, qualify: ‘yes’, label: ‘k’

# %%
import pandas as pd
import numpy as np
exam_data  = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df = pd.DataFrame(exam_data , index=labels)
print("Original rows:")
df
# Out:
# Original rows:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
df.qualify=df.qualify.map({'yes':True,'no':False})

# %%
df
# Out:
#         name  score  attempts  qualify
# a  Anastasia   12.5         1     True
# b       Dima    9.0         3    False
# c  Katherine   16.5         2     True
# d      James    NaN         3    False
# e      Emily    9.0         2    False
# f    Michael   20.0         3     True
# g    Matthew   14.5         1     True
# h      Laura    NaN         1    False
# i      Kevin    8.0         2    False
# j      Jonas   19.0         1     True

# %% [markdown]
# Change the name 'James' to 'Suresh' in name column of the DataFrame

# %%
df.name=df.name.replace('James','Surash')

# %%
df
# Out:
#         name  score  attempts  qualify
# a  Anastasia   12.5         1     True
# b       Dima    9.0         3    False
# c  Katherine   16.5         2     True
# d     Surash    NaN         3    False
# e      Emily    9.0         2    False
# f    Michael   20.0         3     True
# g    Matthew   14.5         1     True
# h      Laura    NaN         1    False
# i      Kevin    8.0         2    False
# j      Jonas   19.0         1     True

# %% [markdown]
# rite a Pandas program to delete the 'attempts' column from the DataFrame.

# %%
df.pop('attempts')
# Out:
# a    1
# b    3
# c    2
# d    3
# e    2
# f    3
# g    1
# h    1
# i    2
# j    1
# Name: attempts, dtype: int64

# %%
df
# Out:
#         name  score  qualify
# a  Anastasia   12.5     True
# b       Dima    9.0    False
# c  Katherine   16.5     True
# d     Surash    NaN    False
# e      Emily    9.0    False
# f    Michael   20.0     True
# g    Matthew   14.5     True
# h      Laura    NaN    False
# i      Kevin    8.0    False
# j      Jonas   19.0     True

# %% [markdown]
# Write a Pandas program to insert a new column in existing DataFrame.

# %%
attempts=[1,2,1,2,2,1,2,1,1,1]

# %%
df['attempts']=attempts

# %%
df
# Out:
#         name  score  qualify
# a  Anastasia   12.5     True
# b       Dima    9.0    False
# c  Katherine   16.5     True
# d     Surash    NaN    False
# e      Emily    9.0    False
# f    Michael   20.0     True
# g    Matthew   14.5     True
# h      Laura    NaN    False
# i      Kevin    8.0    False
# j      Jonas   19.0     True
